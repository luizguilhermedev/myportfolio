# %% [markdown]
# <a href="https://colab.research.google.com/github/luizguilhermedev/myportfolio/blob/main/lunar_lander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Deep reinforcement Learning agent 🤖 🧠
#
# A lunar lander that will learn to land correctly on the Moon 🌝
#
# ### Environment
#
# * We're going to use `LunarLander-v2`
# * `Stable-Baselines3`for the library
#
#
# ### Dependencies
#
# * `gymnasium[box2d]`: Contains the LunarLander-v2 environment 🌛
#
# * `stable-baselines3[extra]`: The deep reinforcement learning library.
#
# * `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
#
#
# ## Problem
#
# **Being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine.**
#
#
# ## Evaluation
#
# Obtain 200+ with our Agent

# %%
# !apt install swig cmake

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
# ...
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from
# huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (0.20.2)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (1.1.2)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 327, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 119, in publish_display_data
#     display_pub.publish(
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 115, in publish
#     self._flush_streams()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 82, in _flush_streams
#     sys.stdout.flush()
#   File "/usr/local/lib/python3.10/dist-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1673, in print
#     with self:
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "/usr/local/lib/python3.10/dist-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/display.py", line 320, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py", line 146, in format
#     if self.ipython_display_formatter(obj):
#   File "<decorator-gen-4>", line 2, in __call__
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py", line 230, in catch_format_error
#     ip = get_ipython()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/getipython.py", line 24, in get_ipython
#     return InteractiveShell.instance()
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/configurable.py", line 558, in instance
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from
# huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from
# huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from
# huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from
# huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from
# huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (23.2)
#     if isinstance(cls._instance, cls):
# RecursionError: maximum recursion depth exceeded in __instancecheck__
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from
# torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from
# torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from
# torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from
# torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from
# matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from
# pandas->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from
# python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from
# jinja2->torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from
# requests->huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from
# requests->huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from
# requests->huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from
# requests->huggingface-hub~=0.8->huggingface_sb3->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4))
# (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from
# sympy->torch>=1.11->stable-baselines3==2.0.0a5->-r
# https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
# (1.3.0)

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# This cell will force the runtime to crash, so we'll need to connect again and run the code starting from here

import os
os.kill(os.getpid(),9)

# %%
# Virtual display

from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8e2de311636b> in <cell line: 3>()
#       1 # Virtual display
#       2
# ----> 3 from pyvirtualdisplay import Display
#       4
#       5 virtual_display = Display(visible=0, size=(1400, 900))
#
# ModuleNotFoundError: No module named 'pyvirtualdisplay'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ## Gymnasium 🤖 🏋
#
# This library contains our environment
#
# Gymnasium library provides two things:
#
# * An interface that allows us to create **RL environments**
# * A collection of environments(such as gym-control, atari, box2D...)
#
# Steps:
#
# * Agent receives state (S0) from the environment
# * Based on that stat (S0), the Agent taken an action (A0)
# * Environment transitions to new state (S1)
# * Environment gives some reward(R1)
#
# Gymnasium:
#
# * Create our environment using `gymnasium.make()`
# * Reset the environment to its initial state with `observation = env.reset()`
# * Get an action using our model
# * `env.step(action)`

# %%
import gymnasium as gym

# Creating environment called LunarLander-v2

env = gym.make("LunarLander-v2")

# Reset this environment

observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # if the game is terminated (landed, crashed) or truncated (timeout)

  if terminated or truncated:
    # reset the environment
    print("Environment is reset")
    observation, info = env.reset()

env.close()
# Out:
# Action taken: 1
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 1

# %% [markdown]
# Let's take a quick look what our Environment looks like:

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-59.000328   -66.81401     -0.65032095   3.9472764   -3.1135836
#   -1.5826339    0.19677278   0.92187774]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 0

# %% [markdown]
# ## Vectorized Environment
#
# Stacking multiple independent environments into a single environment

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Creating our Model 🤖
#
#
# * Deep RL library: Stable Baselines3(SB3)
# * SB3 is  set of reliable implementations of reinforcement learning algotithms in PyTorch.
#
# SB3 basic steps:
#
# * 1. Create an environment
# * 2. Define the model we want to use `model = PPO("MlpPolicy)`
# * 3. Train the agent with `model.learn`

# %%
# Create environment

env = gym.make("LunarLander-v2")

# Instantiate the agent

model = PPO('MlpPolicy', env, verbose=1)

# Train the agent

# model.learn(total_timesteps=int(2e5))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Fine-tuning to accelerate the trainig

model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Let's train it for 2,000,000 timesteps
model.learn(total_timesteps=200000, progress_bar=True)

# and let's save the model

model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.7     |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    fps             | 463      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 88.8          |
# |    ep_rew_mean          | -191          |
# | time/                   |               |
# |    fps                  | 483           |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00057189504 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.00135      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.09e+03      |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.00178      |
# |    value_loss           | 7.4e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.1         |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 496          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0009335616 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00674      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 5.18e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.9          |
# |    ep_rew_mean          | -172          |
# | time/                   |               |
# |    fps                  | 503           |
# |    iterations           | 4             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00055511144 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0356       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.87e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 4.59e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.9         |
# |    ep_rew_mean          | -176         |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0003878341 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -5.42e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.43e+03     |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 5.99e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.5          |
# |    ep_rew_mean          | -183          |
# | time/                   |               |
# |    fps                  | 510           |
# |    iterations           | 6             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00041302515 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0162       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.002        |
# |    value_loss           | 5.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.5          |
# |    ep_rew_mean          | -178          |
# | time/                   |               |
# |    fps                  | 492           |
# |    iterations           | 7             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00017903117 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0142       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.56e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.000797     |
# |    value_loss           | 9.24e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.3          |
# |    ep_rew_mean          | -174          |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 8             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00025772012 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0014       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.53e+03      |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.000664     |
# |    value_loss           | 3.19e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.5         |
# |    ep_rew_mean          | -173         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0008267531 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00343     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+03     |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 2.41e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -170         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 10           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0030609309 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0231       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+03     |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 3.23e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 106           |
# |    ep_rew_mean          | -169          |
# | time/                   |               |
# |    fps                  | 494           |
# |    iterations           | 11            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00051677204 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.1           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 829           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 1.6e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 496          |
# |    iterations           | 12           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0007605248 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0513      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5e+03      |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 5.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -165         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 13           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0015898885 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000531    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+03     |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 3.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -162         |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0005270063 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000459    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 846          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.000659    |
# |    value_loss           | 1.79e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 107           |
# |    ep_rew_mean          | -150          |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 15            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 0.00034952594 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00643      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 916           |
# |    n_updates            | 56            |
# |    policy_gradient_loss | -0.000996     |
# |    value_loss           | 2.19e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -145          |
# | time/                   |               |
# |    fps                  | 491           |
# |    iterations           | 16            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00054567005 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00185      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 793           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 1.37e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 17           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0046940846 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 548          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00566     |
# |    value_loss           | 1.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 18           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0022444543 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00352     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 415          |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 919          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 113           |
# |    ep_rew_mean          | -127          |
# | time/                   |               |
# |    fps                  | 490           |
# |    iterations           | 19            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00037856237 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -0.00286      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 492           |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.00148      |
# |    value_loss           | 1.07e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 20           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0007189992 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.019       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 906          |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 21           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0009452638 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00375     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 562          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 1.81e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 107           |
# |    ep_rew_mean          | -110          |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 22            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00032961386 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 0.000102      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 602           |
# |    n_updates            | 84            |
# |    policy_gradient_loss | -0.000657     |
# |    value_loss           | 1.3e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 23           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0006657689 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00114     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 457          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 1e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 24           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0034825716 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.000544    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 440          |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 747          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 25           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0011069505 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+03      |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 2.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 26          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009949534 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.000383   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 373         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 792         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 114          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 27           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0028549137 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.000472    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 611          |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 984          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 28           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0026618298 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0059      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 939          |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 1.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 29          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.013508439 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.000479   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 202         |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 574         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 30           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0066050445 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.000123    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 498          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00616     |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 116        |
# |    ep_rew_mean          | -112       |
# | time/                   |            |
# |    fps                  | 488        |
# |    iterations           | 31         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.00107256 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | -0.00059   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 511        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.000822  |
# |    value_loss           | 1.01e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 32           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0006262994 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.00292     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 586          |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 1.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 33           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0057383114 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.000482    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 140          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 385          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 34          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008079966 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 183         |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 473         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 35           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0014209372 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 202          |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 595          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -93.6       |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 36          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009295499 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.00195    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 282         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 582         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -91.1       |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 37          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.009050797 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.00317     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 461         |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.000139    |
# |    value_loss           | 856         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | -87.3        |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 38           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0017380028 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.8         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 90.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 39          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.012643893 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.00157    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 343         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 139           |
# |    ep_rew_mean          | -86.1         |
# | time/                   |               |
# |    fps                  | 486           |
# |    iterations           | 40            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 7.5356744e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | -0.146        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 455           |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.000457     |
# |    value_loss           | 1.39e+03      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 141        |
# |    ep_rew_mean          | -78.7      |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 41         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.00958996 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | -0.00216   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 313        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00445   |
# |    value_loss           | 485        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 144           |
# |    ep_rew_mean          | -74.5         |
# | time/                   |               |
# |    fps                  | 488           |
# |    iterations           | 42            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00014424941 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | -0.00217      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 226           |
# |    n_updates            | 164           |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 400           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 146           |
# |    ep_rew_mean          | -69.5         |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 43            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 3.9335166e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | -0.00566      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 214           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | -0.000285     |
# |    value_loss           | 507           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | -69.1       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 44          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009716857 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.000374   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 326         |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 607         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 157           |
# |    ep_rew_mean          | -64.1         |
# | time/                   |               |
# |    fps                  | 486           |
# |    iterations           | 45            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 0.00053489965 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | -0.00952      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 589           |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.00151      |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | -57.5        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 46           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0024524303 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.029        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 353          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 160           |
# |    ep_rew_mean          | -53.3         |
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 47            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.00017917884 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | -0.00165      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 196           |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.000208     |
# |    value_loss           | 422           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | -52.9       |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 48          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014352514 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.00361    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 262         |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.0005     |
# |    value_loss           | 474         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -51.3        |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 49           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0033889436 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0251       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 151          |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 306          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -47.3        |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 50           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0011921888 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.0499       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 133          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 213          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 190          |
# |    ep_rew_mean          | -45.9        |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 51           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 4.930509e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.0115      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 381          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000156    |
# |    value_loss           | 877          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | -43.6       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 52          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006577671 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.5        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 154         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 190           |
# |    ep_rew_mean          | -45.9         |
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 53            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 0.00030019175 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.18         |
# |    explained_variance   | -0.0342       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 422           |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -8.81e-05     |
# |    value_loss           | 554           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | -47.4        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 54           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 7.247145e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0056263525 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.9         |
# |    n_updates            | 708          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 50.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 50.7        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 179         |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 183296      |
# | train/                  |             |
# |    approx_kl            | 0.011028709 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.37        |
# |    n_updates            | 712         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 22.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 50.4         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 180          |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0036103907 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.84         |
# |    n_updates            | 716          |
# |    policy_gradient_loss | -0.00728     |
# |    value_loss           | 32           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 50.3         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 181          |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 185344       |
# | train/                  |              |
# |    approx_kl            | 0.0041998113 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.9         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.000802    |
# |    value_loss           | 182          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 803         |
# |    ep_rew_mean          | 53.4        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 182         |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006920447 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96        |
# |    n_updates            | 724         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 10          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 810          |
# |    ep_rew_mean          | 55.7         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 183          |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 187392       |
# | train/                  |              |
# |    approx_kl            | 0.0007576828 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.694        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 728          |
# |    policy_gradient_loss | 0.000207     |
# |    value_loss           | 329          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 809        |
# |    ep_rew_mean          | 56.6       |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 184        |
# |    time_elapsed         | 394        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00434836 |
# |    clip_fraction        | 0.0264     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.3       |
# |    n_updates            | 732        |
# |    policy_gradient_loss | -0.0033    |
# |    value_loss           | 57         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 61.5         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 185          |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 189440       |
# | train/                  |              |
# |    approx_kl            | 0.0015895433 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 175          |
# |    n_updates            | 736          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 404          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 821          |
# |    ep_rew_mean          | 63.5         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 186          |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0010579915 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 221          |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 380          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 65.7        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 187         |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 191488      |
# | train/                  |             |
# |    approx_kl            | 0.009558815 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 744         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 65.6        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 188         |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.010304518 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 748         |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 828          |
# |    ep_rew_mean          | 66           |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 189          |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 193536       |
# | train/                  |              |
# |    approx_kl            | 0.0057772174 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 752          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 52.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | 65.2        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 190         |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008123967 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89        |
# |    n_updates            | 756         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 12.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 828          |
# |    ep_rew_mean          | 66.5         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 191          |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 195584       |
# | train/                  |              |
# |    approx_kl            | 0.0004415727 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.2         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | 0.000151     |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 828          |
# |    ep_rew_mean          | 67.8         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 192          |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0041261627 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85         |
# |    n_updates            | 764          |
# |    policy_gradient_loss | -0.00066     |
# |    value_loss           | 26.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 828          |
# |    ep_rew_mean          | 68.8         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 193          |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 197632       |
# | train/                  |              |
# |    approx_kl            | 0.0011206974 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 768          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 330          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 828        |
# |    ep_rew_mean          | 69.5       |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 194        |
# |    time_elapsed         | 415        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00908433 |
# |    clip_fraction        | 0.0305     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.93       |
# |    n_updates            | 772        |
# |    policy_gradient_loss | -0.000767  |
# |    value_loss           | 14.7       |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 844           |
# |    ep_rew_mean          | 71.9          |
# | time/                   |               |
# |    fps                  | 477           |
# |    iterations           | 196           |
# |    time_elapsed         | 420           |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00047040032 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.806         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 171           |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -4.85e-06     |
# |    value_loss           | 242           |
# -------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Evaluating our Agent 🤖 🦾
#
# * Wrap the environment in a Monitor
# * SB3 provides a method to do that: `evaluate_policy`

# %%
# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.

eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(
    model, eval_env, n_eval_episodes=10, deterministic=True)

print(f'Mean Reward = {mean_reward:.2f} +/- {std_reward}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95c9e868aa9b> in <cell line: 6>()
#       4 #       wrap environment in a "Monitor" wrapper before other wrappers.
#       5
# ----> 6 eval_env = Monitor(gym.make("LunarLander-v2"))
#       7 mean_reward, std_reward = evaluate_policy(
#       8     model, eval_env, n_eval_episodes=10, deterministic=True)
#
# NameError: name 'Monitor' is not defined

# %% [markdown]
# ## WELL DONE!
#
# Our agent has trained 1500000 times and got 227 points
#
# **Note:** It's possible to improve our model even more, trying different hyperparameters

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "luizguilherme/ppo-LunarLander-v2"

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmpzovzpot6/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpzovzpot6/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpzovzpot6/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpzovzpot6/-step-0-to-step-1000.mp4
# ℹ Pushing repo luizguilherme/ppo-LunarLander-v2 to the Hugging Face
# Hub
# policy.pth:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# policy.optimizer.pth:   0%|          | 0.00/88.4k [00:00<?, ?B/s]
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/luizguilherme/ppo-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/luizguilherme/ppo-LunarLander-v2/commit/bace930010320b474f1def26158037001eebbc3c', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='bace930010320b474f1def26158037001eebbc3c', pr_url=None, pr_revision=None, pr_num=None)

# %%
# !pip install shimmy
# Out:
# Collecting shimmy
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.23.5)
# Requirement already satisfied: gymnasium>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (0.28.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (0.0.4)
# Installing collected packages: shimmy
# Successfully installed shimmy-1.3.0

# %%
from huggingface_sb3 import load_from_hub
repo_id = "luizguilherme/ppo-LunarLander-v2" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.1.58+-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# - Python: 3.10.12
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.1.0+cu121
# - GPU Enabled: True
# - Numpy: 1.23.5
# - Cloudpickle: 2.2.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.1.58+-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# - Python: 3.10.12
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.1.0+cu121
# - GPU Enabled: True
# - Numpy: 1.23.5
# - Cloudpickle: 2.2.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=227.50 +/- 71.30534253531057
